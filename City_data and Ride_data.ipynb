# %%
# Add Matplotlib magic command
# %matplotlib inline

# Add Dependances:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the city data file and store it in a pandas DataFrame.
city_data = pd.read_csv("C:/Users/avnit/PyBer_Analysis/Resources/city_data.csv")
city_data.head(10)
# Out:
#             city  driver_count   type
# 0    Richardfort            38  Urban
# 1   Williamsstad            59  Urban
# 2    Port Angela            67  Urban
# 3     Rodneyfort            34  Urban
# 4    West Robert            39  Urban
# 5   West Anthony            70  Urban
# 6    West Angela            48  Urban
# 7  Martinezhaven            25  Urban
# 8      Karenberg            22  Urban
# 9    Barajasview            26  Urban

# %%
ride_data=pd.read_csv("C:/Users/avnit/PyBer_Analysis/Resources/ride_data.csv")
ride_data.head(10)
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
# 5        South Latoya  2019-03-11 12:26:48   9.52  1994999424437
# 6       New Paulville  2019-02-27 11:17:56  43.25   793208410091
# 7        Simpsonburgh  2019-04-26 00:43:24  35.98   111953927754
# 8     South Karenland  2019-01-08 03:28:48  35.09  7995623208694
# 9       North Jasmine  2019-03-09 06:26:29  42.81  5327642267789

# %%
# Checking null values
city_data.isna().sum()
# Out:
# city            0
# driver_count    0
# type            0
# dtype: int64

# %%
# Checking datatypes

city_data.dtypes
# Out:
# city            object
# driver_count     int64
# type            object
# dtype: object

# %%
# Get the unique values of the type of city.
city_data["type"].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
# Get the number of data points from the Urban cities.
sum(city_data["type"]=="Urban")
# Out:
# 66

# %%
# Get the number of data points from Suburban
sum(city_data["type"]=="Suburban")
# Out:
# 36

# %%
# Get the number of data points from Rural
sum(city_data["type"]=="Rural")
# Out:
# 18

# %%
# Checking last 10 rows
city_data.tail()
# Out:
#                 city  driver_count   type
# 115     Bradshawfurt             7  Rural
# 116     New Ryantown             2  Rural
# 117   Randallchester             9  Rural
# 118      Jessicaport             1  Rural
# 119  South Saramouth             7  Rural

# %%
# Get the columns and the rows that are not null.
ride_data.count()
# Out:
# city       2375
# date       2375
# fare       2375
# ride_id    2375
# dtype: int64

# %%
# Checking null values
ride_data.isna().sum()
# Out:
# city       0
# date       0
# fare       0
# ride_id    0
# dtype: int64

# %%
# Checking the data types of each column
ride_data.dtypes
# Out:
# city        object
# date        object
# fare       float64
# ride_id      int64
# dtype: object

# %%
# Combining two data sets
pyber_data=pd.merge(ride_data,city_data,how="left",on=["city","city"])
pyber_data.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
# Create the Urban city Data Frame
urban_city= pyber_data[pyber_data["type"]=="Urban"]
urban_city
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 1620        Reynoldsfurt  2019-02-14 11:25:10  39.40  9070692324754
# 1621     Christopherfurt  2019-03-13 01:47:52  32.05  2788817929605
# 1622        Raymondhaven  2019-03-20 02:20:34  38.53  8658255136559
# 1623       Port Johnbury  2019-03-26 07:22:45   7.63  8089282605778
# 1624        West Gabriel  2019-05-05 01:24:06  27.57  4428773411209
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
# Create the Suburban Data Frame
suburban_city = pyber_data[pyber_data["type"]=="Suburban"]
suburban_city
# Out:
#                  city                 date   fare        ride_id  \
# 1625    Barronchester  2019-01-27 03:08:01  27.79  6653622887913
# 1626    East Kentstad  2019-04-07 19:44:19  18.75  6575961095852
# 1627        Lake Omar  2019-01-17 21:33:35  21.71   966911700371
# 1628       Myersshire  2019-02-27 17:38:39  17.10  5706770909868
# 1629      West Hannah  2019-04-19 01:06:59  37.78  2273047151891
# ...               ...                  ...    ...            ...
# 2245      West Hannah  2019-03-02 17:06:03  13.92  7388937249208
# 2246  Lake Robertside  2019-04-03 03:27:45  12.76  1301757653884
# 2247      Colemanland  2019-01-10 06:49:58  27.70  8704067171414
# 2248   East Marymouth  2019-02-12 23:18:53  47.41  7409660239158
# 2249      New Raymond  2019-02-11 17:28:27  17.97  7551674475043
#
#       driver_count      type
# 1625            11  Suburban
# 1626            20  Suburban
# 1627            22  Suburban
# 1628            19  Suburban
# 1629            12  Suburban
# ...

# %%
# Create Rural Data Frame
rural_city= pyber_data[pyber_data["type"]=="Rural"]
rural_city
# Out:
#                  city                 date   fare        ride_id  \
# 2250   Randallchester  2019-04-13 11:13:31  43.22  1076079536213
# 2251      North Holly  2019-02-02 14:54:00  12.42  1985256326182
# 2252      Michaelberg  2019-03-27 18:27:34  54.85  4421836952718
# 2253  Lake Latoyabury  2019-02-23 21:12:24  47.90  3269652929887
# 2254  Lake Latoyabury  2019-05-06 08:57:56  51.80  4018025271936
# ...               ...                  ...    ...            ...
# 2370      Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371  Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372      North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373     West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374       Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 2250             9  Rural
# 2251             8  Rural
# 2252             6  Rural
# 2253             2  Rural
# 2254             2  Rural
# ...

# %%
# Get the number of rides for urban cities.
urban_ride_count=urban_city.groupby(["city"]).count()["ride_id"]
urban_ride_count
# Out:
# city
# Amandaburgh            18
# Barajasview            22
# Carriemouth            27
# Christopherfurt        27
# Deanville              19
#                        ..
# West Patrickchester    16
# West Robert            31
# West Samuelburgh       25
# Williamsstad           23
# Williamsview           20
# Name: ride_id, Length: 66, dtype: int64

# %%
# Get the number of rides for sunurban cities
suburban_ride_count=suburban_city.groupby(["city"]).count()["ride_id"]
suburban_ride_count
# Out:
# city
# Barronchester         16
# Bethanyland           18
# Brandonfort           19
# Colemanland           22
# Davidfurt             17
# East Aaronbury         9
# East Danielview       17
# East Kentstad         13
# East Marymouth        27
# Grayville             15
# Josephside            27
# Lake Ann              12
# Lake Omar             14
# Lake Robertside       25
# Lake Scott            18
# Lewishaven            12
# Lewisland             17
# Mezachester           17
# Myersshire            16
# New Olivia            17
# New Raymond           22
# New Shannonberg       17
# Nicolechester         19
# North Jeffrey         13
# North Richardhaven    14
# North Timothy         15
# Port Shane            19
# Rodriguezview         15
# Sotoville             11
# South Brenda          24
# South Teresa          22
# Veronicaberg          17
# Victoriaport          14
# West Hannah           21
# West Kimmouth         20
# Williamsonville       14
# ...

# %%
# Get the number of rides in rural cities
rural_ride_count=rural_city.groupby(["city"]).count()["ride_id"]
rural_ride_count
# Out:
# city
# Bradshawfurt         10
# Garzaport             3
# Harringtonfort        6
# Jessicaport           6
# Lake Jamie            6
# Lake Latoyabury      11
# Michaelberg          12
# New Ryantown          6
# Newtonview            4
# North Holly           9
# North Jaime           8
# Penaborough           5
# Randallchester        5
# South Jennifer        7
# South Marychester     8
# South Saramouth       4
# Taylorhaven           6
# West Heather          9
# Name: ride_id, dtype: int64

# %%
# Get the average fare for Urban cities
urban_fare = urban_city.groupby(["city"]).mean()["fare"]
urban_fare
# Out:
# city
# Amandaburgh            24.641667
# Barajasview            25.332273
# Carriemouth            28.314444
# Christopherfurt        24.501852
# Deanville              25.842632
#                          ...
# West Patrickchester    28.233125
# West Robert            25.123871
# West Samuelburgh       21.767600
# Williamsstad           24.362174
# Williamsview           26.599000
# Name: fare, Length: 66, dtype: float64

# %%
# Get the average fare for Suburban cities
suburban_fare = suburban_city.groupby(["city"]).mean()["fare"]
suburban_fare
# Out:
# city
# Barronchester         36.422500
# Bethanyland           32.956111
# Brandonfort           35.437368
# Colemanland           30.894545
# Davidfurt             31.995882
# East Aaronbury        25.661111
# East Danielview       31.560588
# East Kentstad         29.823077
# East Marymouth        30.835185
# Grayville             27.763333
# Josephside            32.858148
# Lake Ann              30.890000
# Lake Omar             28.075000
# Lake Robertside       31.262000
# Lake Scott            31.886111
# Lewishaven            25.241667
# Lewisland             34.614118
# Mezachester           30.760000
# Myersshire            30.203125
# New Olivia            34.054118
# New Raymond           27.961818
# New Shannonberg       28.378235
# Nicolechester         30.909474
# North Jeffrey         29.242308
# North Richardhaven    24.704286
# North Timothy         31.262000
# Port Shane            31.077895
# Rodriguezview         30.745333
# Sotoville             31.980000
# ...

# %%
# Get the average fare for Rural cities
rural_fare= rural_city.groupby(["city"]).mean()["fare"]
rural_fare
# Out:
# city
# Bradshawfurt         40.064000
# Garzaport            24.123333
# Harringtonfort       33.470000
# Jessicaport          36.013333
# Lake Jamie           34.358333
# Lake Latoyabury      26.061818
# Michaelberg          34.997500
# New Ryantown         43.278333
# Newtonview           36.745000
# North Holly          29.130000
# North Jaime          30.802500
# Penaborough          35.246000
# Randallchester       29.742000
# South Jennifer       35.264286
# South Marychester    41.870000
# South Saramouth      36.160000
# Taylorhaven          42.263333
# West Heather         33.890000
# Name: fare, dtype: float64

# %%
# Get the average number of drivers for each urban city.
urban_driver_count = urban_city.groupby(["city"]).mean()["driver_count"]
urban_driver_count.head()
# Out:
# city
# Amandaburgh        12.0
# Barajasview        26.0
# Carriemouth        52.0
# Christopherfurt    41.0
# Deanville          49.0
# Name: driver_count, dtype: float64

# %%
# Get the average number of drivers for Suburban city
suburban_driver_count= suburban_city.groupby(["city"]).mean()["driver_count"]
suburban_driver_count
# Out:
# city
# Barronchester         11.0
# Bethanyland           22.0
# Brandonfort           10.0
# Colemanland           23.0
# Davidfurt             23.0
# East Aaronbury         7.0
# East Danielview       22.0
# East Kentstad         20.0
# East Marymouth         5.0
# Grayville              2.0
# Josephside            25.0
# Lake Ann               3.0
# Lake Omar             22.0
# Lake Robertside        4.0
# Lake Scott            23.0
# Lewishaven            23.0
# Lewisland              4.0
# Mezachester           14.0
# Myersshire            19.0
# New Olivia            20.0
# New Raymond           17.0
# New Shannonberg       20.0
# Nicolechester         19.0
# North Jeffrey         11.0
# North Richardhaven     1.0
# North Timothy          7.0
# Port Shane             7.0
# Rodriguezview         20.0
# Sotoville             10.0
# South Brenda           1.0
# South Teresa          21.0
# Veronicaberg          20.0
# Victoriaport          16.0
# West Hannah           12.0
# ...

# %%
# get the average number of drivers for Rural
rural_driver_count= rural_city.groupby(["city"]).mean()["driver_count"]
rural_driver_count
# Out:
# city
# Bradshawfurt         7.0
# Garzaport            7.0
# Harringtonfort       4.0
# Jessicaport          1.0
# Lake Jamie           4.0
# Lake Latoyabury      2.0
# Michaelberg          6.0
# New Ryantown         2.0
# Newtonview           1.0
# North Holly          8.0
# North Jaime          1.0
# Penaborough          6.0
# Randallchester       9.0
# South Jennifer       7.0
# South Marychester    1.0
# South Saramouth      7.0
# Taylorhaven          1.0
# West Heather         4.0
# Name: driver_count, dtype: float64

# %%
# Scatter Plot for Urban Cities
plt.scatter(urban_ride_count,urban_fare,
            s=10*urban_driver_count,
            color="coral",
            edgecolor="black",
            linewidth=1,
            alpha = 0.8,
            label="Urban")
plt.title("PyBer Ride-Sharing Data(2019)")
plt.ylabel("Average Fare($)")
plt.xlabel("Total Number of Rides(Per City)")
plt.legend()
plt.grid(True)

# %%
# Creating Scatter Plot for Suburban cities
plt.scatter(suburban_ride_count,suburban_fare,
           color="skyblue",
           s=10*suburban_driver_count,
           alpha=0.80,
           edgecolor="black",linewidth=1,
           label="Suburban")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
plt.legend()

# %%
# Creating scatter chart for Rural
plt.scatter(rural_driver_count,
      rural_fare,
      s=10*rural_driver_count, c="gold",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Rural")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")


plt.grid(True)

plt.legend()

# %%
# Scatter the plot in one chart

plt.subplots(figsize=(10,6))

plt.scatter(urban_ride_count,urban_fare,
            s=10*urban_driver_count,
            color="coral",
            edgecolor="black",
            linewidth=1,
            alpha = 0.8,
            label="Urban")



plt.scatter(suburban_ride_count,suburban_fare,
           color="skyblue",
           s=10*suburban_driver_count,
           alpha=0.80,
           edgecolor="black",linewidth=1,
           label="Suburban")



plt.scatter(rural_driver_count,
      rural_fare,
      s=10*rural_driver_count, c="gold",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Rural")


plt.title("PyBer Ride-Sharing Data (2019)",fontsize=20)
plt.ylabel("Average Fare ($)",fontsize=12)
plt.xlabel("Total Number of Rides (Per City)",fontsize=12)
plt.legend()
plt.grid(True)
plt.xlim(0,40)

# Create a legend
lgnd = plt.legend(fontsize="12",mode="expanded",
         scatterpoints=1, loc="best", title="City Types")
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]
lgnd.get_title().set_fontsize(12)

# Incorporate a text label about circle size.
plt.text(42, 35, "Note: Circle size correlates with driver count per city.", fontsize="12")

plt.show()

# %%
#Get the summary statistics
urban_city.describe()
# Out:
#               fare       ride_id  driver_count
# count  1625.000000  1.625000e+03   1625.000000
# mean     24.525772  4.873485e+12     36.678154
# std      11.738649  2.907440e+12     20.075545
# min       4.050000  1.458810e+10      3.000000
# 25%      14.550000  2.400244e+12     22.000000
# 50%      24.640000  4.711188e+12     37.000000
# 75%      34.580000  7.451579e+12     52.000000
# max      44.970000  9.991538e+12     73.000000

# %%
suburban_city.describe()
# Out:
#              fare       ride_id  driver_count
# count  625.000000  6.250000e+02    625.000000
# mean    30.970128  4.971015e+12     13.712000
# std     10.677508  2.912410e+12      8.042372
# min     12.050000  3.218337e+08      1.000000
# 25%     21.970000  2.364253e+12      5.000000
# 50%     30.750000  5.053221e+12     16.000000
# 75%     39.830000  7.551674e+12     21.000000
# max     49.960000  9.917744e+12     25.000000

# %%
rural_city.describe()
# Out:
#              fare       ride_id  driver_count
# count  125.000000  1.250000e+02    125.000000
# mean    34.623440  4.647746e+12      4.296000
# std     14.558046  2.887834e+12      2.691156
# min     10.110000  2.684873e+10      1.000000
# 25%     19.900000  2.275364e+12      1.000000
# 50%     37.050000  4.023962e+12      4.000000
# 75%     47.070000  7.118047e+12      7.000000
# max     58.550000  9.990581e+12      9.000000

# %%
# Summary statistics of Ride Count
urban_ride_count.describe()
# Out:
# count    66.000000
# mean     24.621212
# std       5.408726
# min      12.000000
# 25%      21.000000
# 50%      24.000000
# 75%      28.000000
# max      39.000000
# Name: ride_id, dtype: float64

# %%
suburban_ride_count.describe()
# Out:
# count    36.000000
# mean     17.361111
# std       4.323707
# min       9.000000
# 25%      14.000000
# 50%      17.000000
# 75%      19.250000
# max      27.000000
# Name: ride_id, dtype: float64

# %%
rural_ride_count.describe()
# Out:
# count    18.000000
# mean      6.944444
# std       2.508157
# min       3.000000
# 25%       5.250000
# 50%       6.000000
# 75%       8.750000
# max      12.000000
# Name: ride_id, dtype: float64

# %%
# Calculate the mean of the ride of each city type
round(urban_ride_count.mean(),2),round(suburban_ride_count.mean(),2),round(rural_ride_count.mean(),2)
# Out:
# (24.62, 17.36, 6.94)

# %%
# Calculate the median of the ride of each city type
round(urban_ride_count.median(),2),round(suburban_ride_count.median(),2),round(rural_ride_count.median(),2)
# Out:
# (24.0, 17.0, 6.0)

# %%
# Calculate the mode of the ride count for the urban cities.
urban_ride_count.mode()
# Out:
# 0    22
# 1    25
# dtype: int64

# %%
# Calculate the mode of the ride count for the suburban cities.
suburban_ride_count.mode()
# Out:
# 0    17
# dtype: int64

# %%
# Calculate the mode of the ride count for the rural cities.
rural_driver_count.mode()
# Out:
# 0    1.0
# dtype: float64

# %%
import scipy.stats as sts

# %%
# Calculate the measures of central tendency for the ride count for the urban cities.
mean_urban_ride_count = np.mean(urban_ride_count)
print(f"The mean for the ride counts for urban trips is {mean_urban_ride_count:.2f}.")

median_urban_ride_count = np.median(urban_ride_count)
print(f"The median for the ride counts for urban trips is {median_urban_ride_count}.")

mode_urban_ride_count = sts.mode(urban_ride_count)
print(f"The mode for the ride counts for urban trips is {mode_urban_ride_count}.")
# Out:
# The mean for the ride counts for urban trips is 24.62.
# The median for the ride counts for urban trips is 24.0.
# The mode for the ride counts for urban trips is ModeResult(mode=array([22], dtype=int64), count=array([7])).

# %%
mode_suburban_ride_count = sts.mode(suburban_ride_count)
print(f"The mode for the ride counts for urban trips is {mode_suburban_ride_count}.")
# Out:
# The mode for the ride counts for urban trips is ModeResult(mode=array([17], dtype=int64), count=array([7])).

# %%
mode_rural_ride_count = sts.mode(rural_ride_count)
print(f"The mode for the ride counts for urban trips is {mode_rural_ride_count}.")
# Out:
# The mode for the ride counts for urban trips is ModeResult(mode=array([6], dtype=int64), count=array([5])).

# %%
# Get the fares for the urban cities.
urban_fares = urban_city["fare"]
urban_fares.head()
# Out:
# 0    13.83
# 1    30.24
# 2    33.44
# 3    23.44
# 4    34.58
# Name: fare, dtype: float64

# %%
# Calculate the measures of central tendency for the average fare for the urban cities.
mean_urban_fares = np.mean(urban_fares)
print(f"The mean fare price for urban trips is ${mean_urban_fares:.2f}.")

median_urban_fares = np.median(urban_fares)
print(f"The median fare price for urban trips is ${median_urban_fares:.2f}.")

mode_rural_fares = sts.mode(urban_fares)
print(f"The mode fare price for urban trips is {mode_rural_fares}.")
# Out:
# The mean fare price for urban trips is $24.53.
# The median fare price for urban trips is $24.64.
# The mode fare price for urban trips is ModeResult(mode=array([22.86]), count=array([5])).

# %%
# Get the fares for the Suburban cities.
suburban_fares = suburban_city["fare"]
suburban_fares.head()
# Out:
# 1625    27.79
# 1626    18.75
# 1627    21.71
# 1628    17.10
# 1629    37.78
# Name: fare, dtype: float64

# %%
suburban_fare.describe()
# Out:
# count    36.000000
# mean     30.737298
# std       2.661333
# min      24.704286
# 25%      29.471291
# 50%      30.902010
# 75%      31.983971
# max      36.422500
# Name: fare, dtype: float64

# %%
# Calculate the measures of central tendency for the average fare for the Suburban cities.
mean_suburban_fares = np.mean(suburban_fare)
print(f"The mean fare price for urban trips is ${mean_suburban_fares:.2f}.")
median_suburban_fares = np.median(suburban_fare)
print(f"The median fare price for urban trips is ${median_suburban_fares:.2f}.")

mode_suburban_fares = sts.mode(suburban_fare)
print(f"The mode fare price for urban trips is {mode_suburban_fares}.")
# Out:
# The mean fare price for urban trips is $30.74.
# The median fare price for urban trips is $30.90.
# The mode fare price for urban trips is ModeResult(mode=array([24.70428571]), count=array([1])).

# %%
# Get the fares for the Rural cities.
rural_fares = rural_city["fare"]
rural_fare.head()
# Out:
# city
# Bradshawfurt      40.064000
# Garzaport         24.123333
# Harringtonfort    33.470000
# Jessicaport       36.013333
# Lake Jamie        34.358333
# Name: fare, dtype: float64

# %%
# Calculate the measures of central tendency for the average fare for the Rural cities.
mean_rural_fares = np.mean(rural_fares)
print(f"The mean fare price for urban trips is ${mean_rural_fares:.2f}.")
median_rural_fares = np.median(rural_fares)
print(f"The median fare price for urban trips is ${median_rural_fares:.2f}.")

mode_rural_fares = sts.mode(rural_fares)
print(f"The mode fare price for urban trips is {mode_rural_fares}.")
# Out:
# The mean fare price for urban trips is $34.62.
# The median fare price for urban trips is $37.05.
# The mode fare price for urban trips is ModeResult(mode=array([37.05]), count=array([2])).

# %%
# Driver Count
# Driver count from Urban cities
urban_driver= urban_city["driver_count"]
urban_driver
# Out:
# 0        5
# 1       72
# 2       57
# 3       34
# 4       46
#         ..
# 1620    67
# 1621    41
# 1622    11
# 1623     3
# 1624    57
# Name: driver_count, Length: 1625, dtype: int64

# %%
# Suburban Driver
suburban_driver=suburban_city["driver_count"]
suburban_driver
# Out:
# 1625    11
# 1626    20
# 1627    22
# 1628    19
# 1629    12
#         ..
# 2245    12
# 2246     4
# 2247    23
# 2248     5
# 2249    17
# Name: driver_count, Length: 625, dtype: int64

# %%
# Rural Driver
rural_driver = rural_city["driver_count"]
rural_driver
# Out:
# 2250    9
# 2251    8
# 2252    6
# 2253    2
# 2254    2
#        ..
# 2370    6
# 2371    2
# 2372    1
# 2373    4
# 2374    1
# Name: driver_count, Length: 125, dtype: int64

# %%
# Calculation the measure of central tendancy of Urban Cities
urban_driver_mean = np.mean(urban_driver)
print(f"The mean driver count for urban cities is ${urban_driver_mean:.2f}.")
urban_driver_median= np.median(urban_driver)
print(f"The median driver count for urban cities is ${urban_driver_median:.2f}.")
urban_driver_mode = sts.mode(urban_driver)
print(f"The mode of driver count for urban cities is ${urban_driver_mode}.")
# Out:
# The mean driver count for urban cities is $36.68.
# The median driver count for urban cities is $37.00.
# The mode of driver count for urban cities is $ModeResult(mode=array([39], dtype=int64), count=array([86])).

# %%
# Calculation the measure of central tendancy of Suburban Cities
suburban_driver_mean = np.mean(suburban_driver)
print(f"The mean driver count for suburban cities is ${suburban_driver_mean:.2f}.")
suburban_driver_median= np.median(suburban_driver)
print(f"The median driver count for suburban cities is ${suburban_driver_median:.2f}.")
suburban_driver_mode = sts.mode(suburban_driver)
print(f"The mode of driver count for suburban cities is ${suburban_driver_mode}.")
# Out:
# The mean driver count for suburban cities is $13.71.
# The median driver count for suburban cities is $16.00.
# The mode of driver count for suburban cities is $ModeResult(mode=array([20], dtype=int64), count=array([79])).

# %%
# Calculation the measure of central tendancy of Rural Cities
rural_driver_mean = np.mean(rural_driver)
print(f"The mean driver count for rural cities is ${rural_driver_mean:.2f}.")
rural_driver_median= np.median(rural_driver)
print(f"The median driver count for rural cities is ${rural_driver_median:.2f}.")
rural_driver_mode = sts.mode(rural_driver)
print(f"The mode of driver count for rural cities is ${rural_driver_mode}.")
# Out:
# The mean driver count for rural cities is $4.30.
# The median driver count for rural cities is $4.00.
# The mode of driver count for rural cities is $ModeResult(mode=array([1], dtype=int64), count=array([32])).

# %%
# Ride Count
# Creating Box and Whisker Plot for Urban Cities:
x_label=["Urban"]
fig,ax=plt.subplots()
ax.boxplot(urban_ride_count,labels=x_label)
# Add title
ax.set_title("Ride Count Data (2019)")
ax.set_ylabel("Number of Rides")
ax.set_yticks(np.arange(10,41,step=2.0))
ax.grid()
plt.show()

# %%
# creating Box and Whisker for Suburban Cities
x_label= ["Suburban"]
fig,ax=plt.subplots()
ax.boxplot(suburban_ride_count,labels=x_label)
ax.set_title("Ride Count Data")
ax.set_ylabel("Number of Rides")
ax.set_yticks(np.arange(0,45,step=3.0))
ax.grid()

# %%
# Creating Box and Whisker for Rural Cities
x_label=["Rural"]
fig,ax=plt.subplots()
ax.boxplot(rural_ride_count,labels=x_label)
ax.set_title("Ride Count Data")
ax.set_xlabel("Rural")
ax.grid()

# %%
# Add all ride count box-and-whisker plots to the same graphs
x_label=["Urban","Suburban","Rural"]
fig,ax=plt.subplots()
ride_count=[urban_ride_count,suburban_ride_count,rural_ride_count]
ax.boxplot(ride_count,labels=x_label)
ax.grid()
ax.set_yticks(np.arange(0,45,step=3.0))
ax.set_title("Ride Count Data(2019)")
ax.set_ylabel("Number of Rides")
ax.set_xlabel("City Types")
plt.show()

# %%
urban_ride_count
# Out:
# city
# Amandaburgh            18
# Barajasview            22
# Carriemouth            27
# Christopherfurt        27
# Deanville              19
#                        ..
# West Patrickchester    16
# West Robert            31
# West Samuelburgh       25
# Williamsstad           23
# Williamsview           20
# Name: ride_id, Length: 66, dtype: int64

# %%
# Get the city that matches 39
urban_city_outliner=urban_ride_count[urban_ride_count==39].index[0]
urban_city_outliner
print(f"{urban_city_outliner} has the highest rider count" )
# Out:
# West Angela has the highest rider count

# %%
# Fare Count
# Creating Box and Whisker for Urban Cities

x_label= ["Urban"]
fig,ax=plt.subplots()
ax.boxplot(urban_fares,labels=x_label)
ax.grid()
ax.set_yticks(np.arange(0,55,step=5.0))
ax.set_title("Ride Fare Data(2019)")
ax.set_ylabel("Fare($USD)")
plt.show()

# %%
# Creating Box and Whisker for Suburban Cities

x_label= ["Suburban"]
fig,ax=plt.subplots()
ax.boxplot(suburban_fares,labels=x_label)
ax.grid()
ax.set_yticks(np.arange(0,55,step=5.0))
ax.set_title("Ride Fare Data(2019)")
ax.set_ylabel("Fare($USD)")
plt.show()

# %%
# Creating Box and Whisker for Rural Cities

x_label= ["Rural"]
fig,ax=plt.subplots()
ax.boxplot(rural_fares,labels=x_label)
ax.grid()
ax.set_yticks(np.arange(0,55,step=5.0))
ax.set_title("Ride Fare Data(2019)")
ax.set_ylabel("Fare($USD)")
plt.show()

# %%
# Bringing all in one graph

x_label=["Urban","Suburban","Rural"]
fig,ax=plt.subplots()
fare_count=[urban_fares,suburban_fares,rural_fares]
ax.boxplot(fare_count,labels=x_label)
ax.set_title("Ride Data (2019)",fontsize=20)
ax.grid()
ax.set_yticks(np.arange(0,80,step=5.0))
ax.set_ylabel('Fares($USD)')
ax.set_xlabel("City Types")
plt.show()

# %%
# Create the box-and-whisker plot for the urban driver count data.
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_driver,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Driver Count Data (2019)')
ax.set_ylabel('Number of Drivers)')
ax.set_yticks(np.arange(0, 90, step=5.0))
ax.grid()
plt.show()
print("Summary Statistics")
urban_driver.describe()
# Out:
# Summary Statistics
# count    1625.000000
# mean       36.678154
# std        20.075545
# min         3.000000
# 25%        22.000000
# 50%        37.000000
# 75%        52.000000
# max        73.000000
# Name: driver_count, dtype: float64

# %%
# Create the box-and-whisker plot for the Suburban driver count data.
x_labels = ["Suburban"]
fig, ax = plt.subplots()
ax.boxplot(suburban_driver,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Driver Count Data (2019)')
ax.set_ylabel('Number of Drivers)')
ax.set_yticks(np.arange(0, 90, step=5.0))
ax.grid()
plt.show()
print("Summary Statistics")
suburban_driver.describe()
# Out:
# Summary Statistics
# count    625.000000
# mean      13.712000
# std        8.042372
# min        1.000000
# 25%        5.000000
# 50%       16.000000
# 75%       21.000000
# max       25.000000
# Name: driver_count, dtype: float64

# %%
# Create the box-and-whisker plot for the Rural driver count data.
x_labels = ["Rural"]
fig, ax = plt.subplots()
ax.boxplot(rural_driver,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Driver Count Data (2019)')
ax.set_ylabel('Number of Drivers)')
ax.set_yticks(np.arange(0, 90, step=5.0))
ax.grid()
plt.show()
print("Summary Statistics")
rural_driver.describe()
# Out:
# Summary Statistics
# count    125.000000
# mean       4.296000
# std        2.691156
# min        1.000000
# 25%        1.000000
# 50%        4.000000
# 75%        7.000000
# max        9.000000
# Name: driver_count, dtype: float64

# %%
x_label=["Urban","Suburban","Rural"]
driver_count = [urban_driver,suburban_driver,rural_driver]
fig,ax=plt.subplots()
ax.boxplot(driver_count,labels=x_label)
ax.grid()
ax.set_title("Driver Count Data(2019)")
ax.set_xlabel("City Types")
ax.set_ylabel("Number of Drivers")
ax.set_yticks(np.arange(0,80,step=5))
plt.show()

# %%
# Pie Chart
# number of ride per city type
pyber_data.groupby(["type"]).count()["ride_id"]
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# Number of ride
pyber_data["ride_id"].count()
# Out:
# 2375

# %%
# Calculate the percentage of rides for each city type
ride_percent=100*pyber_data.groupby(["type"]).count()["ride_id"]/pyber_data["ride_id"].count()
ride_percent
# Out:
# type
# Rural        5.263158
# Suburban    26.315789
# Urban       68.421053
# Name: ride_id, dtype: float64

# %%
# Building the pie chart for each city type
plt.subplots(figsize=(10,6))
plt.pie(ride_percent,
       labels=["Rural","Suburban","Urban"],
       colors=["gold","lightskyblue","lightcoral"],
       explode=[0,0,0.1],
       autopct="%1.1f%%",
       shadow=True,
       startangle=150)
plt.title("% of Total Rides by City Type")

plt.show()

# %%
city_data.groupby(["type"]).sum()["driver_count"]
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
# Calculate Driver percentage
# Calculate the percentage of drivers for each city type.
driver_percents = 100 *city_data.groupby(["type"]).sum()["driver_count"] /city_data["driver_count"].sum()
driver_percents
# Out:
# type
# Rural        2.623613
# Suburban    16.481668
# Urban       80.894719
# Name: driver_count, dtype: float64

# %%
# Build percentage of rides by city type pie chart.
plt.subplots(figsize=(10, 6))
plt.pie(driver_percents,
    labels=["Rural", "Suburban", "Urban"],
    colors=["gold", "lightskyblue", "lightcoral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=165)
plt.title("% of Total Drivers by City Type")

# Show Figure
plt.show()
